# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv("C:\\Users\\gggg\\Downloads\\healthcare.csv")

# %%
df.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 768 entries, 0 to 767
# Data columns (total 9 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Pregnancies               768 non-null    int64
#  1   Glucose                   768 non-null    int64
#  2   BloodPressure             768 non-null    int64
#  3   SkinThickness             768 non-null    int64
#  4   Insulin                   768 non-null    int64
#  5   BMI                       768 non-null    float64
#  6   DiabetesPedigreeFunction  768 non-null    float64
#  7   Age                       768 non-null    int64
#  8   Outcome                   768 non-null    int64
# dtypes: float64(2), int64(7)
# memory usage: 54.1 KB

# %%
df.isna().sum()
# Out:
# Pregnancies                 0
# Glucose                     0
# BloodPressure               0
# SkinThickness               0
# Insulin                     0
# BMI                         0
# DiabetesPedigreeFunction    0
# Age                         0
# Outcome                     0
# dtype: int64

# %%
df['Glucose'].unique()
# Out:
# array([148,  85, 183,  89, 137, 116,  78, 115, 197, 125, 110, 168, 139,
#        189, 166, 100, 118, 107, 103, 126,  99, 196, 119, 143, 147,  97,
#        145, 117, 109, 158,  88,  92, 122, 138, 102,  90, 111, 180, 133,
#        106, 171, 159, 146,  71, 105, 101, 176, 150,  73, 187,  84,  44,
#        141, 114,  95, 129,  79,   0,  62, 131, 112, 113,  74,  83, 136,
#         80, 123,  81, 134, 142, 144,  93, 163, 151,  96, 155,  76, 160,
#        124, 162, 132, 120, 173, 170, 128, 108, 154,  57, 156, 153, 188,
#        152, 104,  87,  75, 179, 130, 194, 181, 135, 184, 140, 177, 164,
#         91, 165,  86, 193, 191, 161, 167,  77, 182, 157, 178,  61,  98,
#        127,  82,  72, 172,  94, 175, 195,  68, 186, 198, 121,  67, 174,
#        199,  56, 169, 149,  65, 190], dtype=int64)

# %%
# There is 0 value need to be replaced with median

#Glucose
#BloodPressure
#SkinThickness
#Insulin
#BMI

# %%
df[df['Glucose']==0]
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 75             1        0             48             20        0  24.7
# 182            1        0             74             20       23  27.7
# 342            1        0             68             35        0  32.0
# 349            5        0             80             32        0  41.0
# 502            6        0             68             41        0  39.0
#
#      DiabetesPedigreeFunction  Age  Outcome
# 75                      0.140   22        0
# 182                     0.299   21        0
# 342                     0.389   22        0
# 349                     0.346   37        1
# 502                     0.727   41        1

# %%
df['Glucose']=df['Glucose'].replace(0,df['Glucose'].median())

# %%
df['Glucose'].unique()
# Out:
# array([148,  85, 183,  89, 137, 116,  78, 115, 197, 125, 110, 168, 139,
#        189, 166, 100, 118, 107, 103, 126,  99, 196, 119, 143, 147,  97,
#        145, 117, 109, 158,  88,  92, 122, 138, 102,  90, 111, 180, 133,
#        106, 171, 159, 146,  71, 105, 101, 176, 150,  73, 187,  84,  44,
#        141, 114,  95, 129,  79,  62, 131, 112, 113,  74,  83, 136,  80,
#        123,  81, 134, 142, 144,  93, 163, 151,  96, 155,  76, 160, 124,
#        162, 132, 120, 173, 170, 128, 108, 154,  57, 156, 153, 188, 152,
#        104,  87,  75, 179, 130, 194, 181, 135, 184, 140, 177, 164,  91,
#        165,  86, 193, 191, 161, 167,  77, 182, 157, 178,  61,  98, 127,
#         82,  72, 172,  94, 175, 195,  68, 186, 198, 121,  67, 174, 199,
#         56, 169, 149,  65, 190], dtype=int64)

# %%
sns.kdeplot(df['Glucose'])
#slightly skewed
# Out:
# <AxesSubplot:xlabel='Glucose', ylabel='Density'>

# %%
sns.boxplot(df['Glucose'])
# Out:
# C:\Users\gggg\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Glucose'>

# %%
count=(df['BloodPressure']==0).sum()
print(count)
# Out:
# 35

# %%
sns.kdeplot(df['BloodPressure'])
# Out:
# <AxesSubplot:xlabel='BloodPressure', ylabel='Density'>

# %%
plt.hist(df['BloodPressure'])
# Out:
# (array([ 35.,   1.,   2.,  13., 107., 261., 243.,  87.,  14.,   5.]),
#  array([  0. ,  12.2,  24.4,  36.6,  48.8,  61. ,  73.2,  85.4,  97.6,
#         109.8, 122. ]),
#  <BarContainer object of 10 artists>)

# %%
df['BloodPressure']=df['BloodPressure'].replace(0,df['BloodPressure'].median())

# %%
sns.kdeplot(df['BloodPressure'])
# Out:
# <AxesSubplot:xlabel='BloodPressure', ylabel='Density'>

# %%
count=(df['SkinThickness']==0).sum()
print(count)
# Out:
# 227

# %%
sns.kdeplot(df['SkinThickness'])
# Out:
# <AxesSubplot:xlabel='SkinThickness', ylabel='Density'>

# %%
df['SkinThickness']=df['SkinThickness'].replace(0,df['SkinThickness'].median())

# %%
sns.kdeplot(df['SkinThickness'])
# Out:
# <AxesSubplot:xlabel='SkinThickness', ylabel='Density'>

# %%
sns.boxplot(df['SkinThickness'])
# Out:
# C:\Users\gggg\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='SkinThickness'>

# %%
#outliars treatment

# %%
ub = df['SkinThickness'].mean() + 2*df['SkinThickness'].std()
lb = df['SkinThickness'].mean() - 2*df['SkinThickness'].std()

# %%
sum(df['SkinThickness'] > ub)
# Out:
# 31

# %%
sum(df['SkinThickness'] < lb)
# Out:
# 4

# %%
df['SkinThickness'][df['SkinThickness']>ub]=ub
df['SkinThickness'][df['SkinThickness']<lb]=lb
# Out:
# <ipython-input-82-d1b487276093>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['SkinThickness'][df['SkinThickness']>ub]=ub

# %%
sns.boxplot(df['SkinThickness'])
# Out:
# C:\Users\gggg\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='SkinThickness'>

# %%
plt.hist(df['SkinThickness'])
# Out:
# (array([ 22.,  37.,  52., 288.,  67.,  83.,  59.,  52.,  60.,  48.]),
#  array([ 8.87660682, 12.56821254, 16.25981826, 19.95142398, 23.6430297 ,
#         27.33463542, 31.02624114, 34.71784686, 38.40945258, 42.1010583 ,
#         45.79266402]),
#  <BarContainer object of 10 artists>)

# %%
count=(df['Insulin']==0).sum()
print(count)
# Out:
# 374

# %%
sns.kdeplot(df['Insulin'])
# Out:
# <AxesSubplot:xlabel='Insulin', ylabel='Density'>

# %%
sns.boxplot(df['Insulin'])
# Out:
# C:\Users\gggg\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Insulin'>

# %%
ubi = df['Insulin'].mean() + df['Insulin'].std()
lbi = df['Insulin'].mean() - df['Insulin'].std()

# %%
sum(df['Insulin'] >ubi)
# Out:
# 90

# %%
df['Insulin'][df['Insulin']>ubi]=ubi
# Out:
# <ipython-input-90-6738b418b312>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Insulin'][df['Insulin']>ubi]=ubi

# %%
count=(df['BMI']==0).sum()
print(count)
# Out:
# 11

# %%
df['BMI']=df['BMI'].replace(0,df['BMI'].median())

# %%
plt.hist(df['BMI'])
# Out:
# (array([ 52., 161., 207., 193.,  91.,  48.,  10.,   4.,   1.,   1.]),
#  array([18.2 , 23.09, 27.98, 32.87, 37.76, 42.65, 47.54, 52.43, 57.32,
#         62.21, 67.1 ]),
#  <BarContainer object of 10 artists>)

# %%
df.head(5)
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72           35.0      0.0  33.6
# 1            1       85             66           29.0      0.0  26.6
# 2            8      183             64           23.0      0.0  23.3
# 3            1       89             66           23.0     94.0  28.1
# 4            0      137             40           35.0    168.0  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1

# %%
sns.set_theme(style="whitegrid")
sns.countplot(data=df, x="BloodPressure", hue="Outcome")
# Out:
# <AxesSubplot:xlabel='BloodPressure', ylabel='count'>

# %%
sns.set_theme(style="whitegrid")
sns.countplot(data=df, x="Age", hue="Outcome")
# Out:
# <AxesSubplot:xlabel='Age', ylabel='count'>

# %%
g = sns.PairGrid(df)
g.map(sns.scatterplot)

# %%
df.head(5)
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72           35.0      0.0  33.6
# 1            1       85             66           29.0      0.0  26.6
# 2            8      183             64           23.0      0.0  23.3
# 3            1       89             66           23.0     94.0  28.1
# 4            0      137             40           35.0    168.0  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1

# %%
g =sns.scatterplot(x= "Glucose" ,y= "BloodPressure",
              hue="Outcome",
              data=df);

#Glucose has positive corelation with outcome

# %%
df.corr()
# Out:
#                           Pregnancies   Glucose  BloodPressure  SkinThickness  \
# Pregnancies                  1.000000  0.128213       0.208615       0.049016
# Glucose                      0.128213  1.000000       0.218937       0.161966
# BloodPressure                0.208615  0.218937       1.000000       0.153899
# SkinThickness                0.049016  0.161966       0.153899       1.000000
# Insulin                     -0.095283  0.260591      -0.070377       0.285438
# BMI                          0.021546  0.231400       0.281132       0.560230
# DiabetesPedigreeFunction    -0.033523  0.137327      -0.002378       0.130660
# Age                          0.544341  0.266909       0.324915       0.044519
# Outcome                      0.221898  0.492782       0.165723       0.191162
#
#                            Insulin       BMI  DiabetesPedigreeFunction  \
# Pregnancies              -0.095283  0.021546                 -0.033523
# ...

# %%
sns.heatmap(df.corr())
# Out:
# <AxesSubplot:>

# %%
plt.subplots(figsize=(10,8))
sns.heatmap(df.corr(),annot=True,cmap='viridis')
# Out:
# <AxesSubplot:>

# %% [markdown]
# # model building

# %%
df.head(5)
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72           35.0      0.0  33.6
# 1            1       85             66           29.0      0.0  26.6
# 2            8      183             64           23.0      0.0  23.3
# 3            1       89             66           23.0     94.0  28.1
# 4            0      137             40           35.0    168.0  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1

# %%
df.describe()
# Out:
#        Pregnancies     Glucose  BloodPressure  SkinThickness     Insulin  \
# count   768.000000  768.000000     768.000000     768.000000  768.000000
# mean      3.845052  121.656250      72.386719      27.125103   64.641814
# std       3.369578   30.438286      12.096642       8.480202   74.516102
# min       0.000000   44.000000      24.000000       8.876607    0.000000
# 25%       1.000000   99.750000      64.000000      23.000000    0.000000
# 50%       3.000000  117.000000      72.000000      23.000000   30.500000
# 75%       6.000000  140.250000      80.000000      32.000000  127.250000
# max      17.000000  199.000000     122.000000      45.792664  195.043482
#
#               BMI  DiabetesPedigreeFunction         Age     Outcome
# count  768.000000                768.000000  768.000000  768.000000
# mean    32.450911                  0.471876   33.240885    0.348958
# std      6.875366                  0.331329   11.760232    0.476951
# ...

# %%
y=df.iloc[:,-1]
X = df.iloc[:,:8]

# %%
X.shape
# Out:
# (768, 8)

# %%
X
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6      148             72      35.000000      0.0  33.6
# 1              1       85             66      29.000000      0.0  26.6
# 2              8      183             64      23.000000      0.0  23.3
# 3              1       89             66      23.000000     94.0  28.1
# 4              0      137             40      35.000000    168.0  43.1
# ..           ...      ...            ...            ...      ...   ...
# 763           10      101             76      45.792664    180.0  32.9
# 764            2      122             70      27.000000      0.0  36.8
# 765            5      121             72      23.000000    112.0  26.2
# 766            1      126             60      23.000000      0.0  30.1
# 767            1       93             70      31.000000      0.0  30.4
#
#      DiabetesPedigreeFunction  Age
# 0                       0.627   50
# 1                       0.351   31
# ...

# %%
y
# Out:
# 0      1
# 1      0
# 2      1
# 3      0
# 4      1
#       ..
# 763    0
# 764    0
# 765    0
# 766    1
# 767    0
# Name: Outcome, Length: 768, dtype: int64

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test = train_test_split(X,
                                                y,
                                                test_size=0.2,
                                                random_state =10)

# %%
#Create model
from sklearn.linear_model import LogisticRegression
model = LogisticRegression()
model.fit(X_train,y_train)
# Out:
# C:\Users\gggg\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:763: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# LogisticRegression()

# %%
print(model.score(X_train,y_train))
print(model.score(X_test,y_test))
# Out:
# 0.7817589576547231
# 0.7467532467532467

# %%
from sklearn.metrics import confusion_matrix
cm = confusion_matrix(y_test,model.predict(X_test))
cm
# Out:
# array([[86,  9],
#        [30, 29]], dtype=int64)

# %%
from sklearn.metrics import classification_report
print(classification_report(y_test,model.predict(X_test)))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.74      0.91      0.82        95
#            1       0.76      0.49      0.60        59
#
#     accuracy                           0.75       154
#    macro avg       0.75      0.70      0.71       154
# weighted avg       0.75      0.75      0.73       154

# %%
#Preparing ROC Curve (Receiver Operating Characteristics Curve)
from sklearn.metrics import roc_curve
from sklearn.metrics import roc_auc_score

# predict probabilities
probs = model.predict_proba(X)
# keep probabilities for the positive outcome only
probs = probs[:, 1]
# calculate AUC
auc = roc_auc_score(y, probs)
print('AUC: %.3f' % auc)
# calculate roc curve
fpr, tpr, thresholds = roc_curve(y, probs)
# plot no skill
plt.plot([0, 1], [0, 1], linestyle='--')
# plot the roc curve for the model
plt.plot(fpr, tpr, marker='.')
# Out:
# AUC: 0.839

# %%
#try with different models
from sklearn.svm import SVR
from sklearn.neighbors import KNeighborsClassifier
from sklearn.tree import DecisionTreeClassifier


from sklearn.pipeline import make_pipeline

# %%
models = [] 
models.append(('KNN', KNeighborsClassifier()))
models.append(('CART', DecisionTreeClassifier(random_state=100)))
models.append(('SVR', SVR()))
models
# Out:
# [('KNN', KNeighborsClassifier()),
#  ('CART', DecisionTreeClassifier(random_state=100)),
#  ('SVR', SVR())]

# %%
scores = []
names = []
for name, model in models:
    model.fit(X_train, y_train)  # training the estimator ...using the TRAIN sET
    names.append(name)
    sc = model.score(X_test, y_test)
    scores.append(sc) # R^2 for the estimator on the TEST SET
    
     
    print(name, '\t:train_score: ', np.round(model.score(X_train, y_train), 3) )
    print(name, '\t:test_score: ', np.round(sc, 3) )
# Out:
# KNN 	:train_score:  0.818
# KNN 	:test_score:  0.721
# CART 	:train_score:  1.0
# CART 	:test_score:  0.721
# SVR 	:train_score:  0.28
# SVR 	:test_score:  0.183

# %%
from sklearn.model_selection import cross_validate
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report

# %%
rf = RandomForestClassifier(n_estimators=1000)
rf.fit(X_train, y_train)
# Out:
# RandomForestClassifier(n_estimators=1000)

# %%
pred = rf.predict(X_test)

# %%
accuracy_score(y_test, pred)
# Out:
# 0.7272727272727273

# %%
cv_rf = cross_validate(rf,X,y, cv=5, return_train_score=True)

# %%
test_rf = np.average(cv_rf["test_score"])

# %%
print(test_rf)
# Out:
# 0.7669807316866141

# %%
from sklearn.model_selection import GridSearchCV

# %%
param_grid_rf = { 
    'n_estimators': [200, 500],
    'max_features': ['auto', 'sqrt', 'log2'],
    'max_depth' : [4,5,6,7,8],
    'criterion' :['gini', 'entropy']
}

# %%
rf_grid = GridSearchCV(estimator=rf, param_grid = param_grid_rf, scoring="accuracy",cv=2, return_train_score=True)

# %%
rf_grid_fit = rf_grid.fit(X,y)

# %%
 rf_grid_fit.best_params_
# Out:
# {'criterion': 'entropy',
#  'max_depth': 7,
#  'max_features': 'sqrt',
#  'n_estimators': 200}

# %%
rf = RandomForestClassifier(criterion="entropy", max_depth=7, max_features="sqrt", n_estimators=200)

# %%
rf.fit(X_train, y_train)
# Out:
# RandomForestClassifier(criterion='entropy', max_depth=7, max_features='sqrt',
#                        n_estimators=200)

# %%
pred = rf.predict(X_test)

# %%
accuracy_score(y_test, pred)
# Out:
# 0.7467532467532467
